# %%
import matplotlib.pyplot as plt
from math import sqrt
from matplotlib import pyplot
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from keras.models import Sequential
from statsmodels.graphics.tsaplots import plot_acf
from keras import layers
from keras.optimizers import Adam
import keras

import math
from keras.layers import LSTM
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping

import yfinance as yf

# %%
def convertToMatrix(data, step,ystep):
        X=[]
        Y=[]
        for i in range((len(data)-step)//12-1):
            d = 12*i+step
            X.append(data[12*i:d,])
            Y.append(data[d:d+ystep,])
        return np.array(X), np.array(Y)

# %%
def step_ahead(y, jump=1):
    y_current = y[:-(jump + 1), 0]
    y_next = y[jump:-1, 0]
    return np.reshape(y_current, (len(y_current), 1)), np.reshape(y_next, (len(y_next), 1))

# %%
START_DATE = '2016-01-01'
END_DATE = '2024-5-28'
ASSET = ['AAPL','TSLA', 'MSFT',"NVDA","GOOGL","AMZN","META"]
prices_df = yf.download(ASSET,start = START_DATE,end = END_DATE)
print(f'Downloaded {prices_df.shape[0]} rows of data.')
prices_df.head()
# Out:
# [*********************100%%**********************]  7 of 7 completed
# Downloaded 2113 rows of data.
# Price       Adj Close                                                         \
# Ticker           AAPL       AMZN      GOOGL        META       MSFT      NVDA
# Date
# 2016-01-04  23.914486  31.849501  37.972000  102.111656  48.521473  7.899907
# 2016-01-05  23.315201  31.689501  38.076500  102.621124  48.742825  8.026811
# 2016-01-06  22.858931  31.632500  37.966499  102.860863  47.857399  7.694904
# 2016-01-07  21.894180  30.396999  37.049999   97.816216  46.192802  7.389841
# 2016-01-08  22.009949  30.352501  36.545502   97.226845  46.334465  7.231207
#
# Price                      Close                        ...       Open  \
# Ticker           TSLA       AAPL       AMZN      GOOGL  ...       MSFT
# Date                                                    ...
# 2016-01-04  14.894000  26.337500  31.849501  37.972000  ...  54.320000
# 2016-01-05  14.895333  25.677500  31.689501  38.076500  ...  54.930000
# 2016-01-06  14.602667  25.174999  31.632500  37.966499  ...  54.320000
# 2016-01-07  14.376667  24.112499  30.396999  37.049999  ...  52.700001
# 2016-01-08  14.066667  24.240000  30.352501  36.545502  ...  52.369999
#
# Price                             Volume                                 \
# Ticker        NVDA       TSLA       AAPL       AMZN     GOOGL      META
# Date
# 2016-01-04  8.0725  15.381333  270597600  186290000  67382000  37912400
# 2016-01-05  8.2450  15.090667  223164000  116452000  45216000  23258200
# 2016-01-06  8.0875  14.666667  273829600  106584000  48206000  25096200
# 2016-01-07  7.6850  14.279333  324377600  141498000  63132000  45172900
# 2016-01-08  7.6675  14.524000  283192000  110258000  47506000  35402300
#
# Price
# Ticker          MSFT      NVDA       TSLA
# Date
# 2016-01-04  53778000  35807600  102406500
# 2016-01-05  34079700  49027200   47802000
# 2016-01-06  39518900  44934400   56686500
# 2016-01-07  56564900  64530400   53314500
# 2016-01-08  48754000  39847200   54421500
#
# [5 rows x 42 columns]

# %%
big_7_return = prices_df['Close'].dropna()
big_7_return.head()
# Out:
# Ticker           AAPL       AMZN      GOOGL        META       MSFT    NVDA  \
# Date
# 2016-01-04  26.337500  31.849501  37.972000  102.220001  54.799999  8.0925
# 2016-01-05  25.677500  31.689501  38.076500  102.730003  55.049999  8.2225
# 2016-01-06  25.174999  31.632500  37.966499  102.970001  54.049999  7.8825
# 2016-01-07  24.112499  30.396999  37.049999   97.919998  52.169998  7.5700
# 2016-01-08  24.240000  30.352501  36.545502   97.330002  52.330002  7.4075
#
# Ticker           TSLA
# Date
# 2016-01-04  14.894000
# 2016-01-05  14.895333
# 2016-01-06  14.602667
# 2016-01-07  14.376667
# 2016-01-08  14.066667

# %%
len(big_7_return)
# Out:
# 2113

# %%
for i in ['AAPL','TSLA', 'MSFT','NVDA','GOOGL','AMZN','META']:
    y=big_7_return[i]
    plt.rcParams['figure.figsize'] = (12,5)
    x=y.index

    plt.plot(x, y, label='close')   
    plt.legend(fontsize=9)
    plt.title(i)
    plt.show()

# %%
df_prediction_RNN = pd.DataFrame(data = {'Observed': y},index = y.index)

# %%
for i in ['AAPL','TSLA', 'MSFT','NVDA','GOOGL','AMZN','META']:
    y=big_7_return[i]
    # 循环神经网络方法训练
    look_back=60
    Tp = 1200
    values = y.values
    #归一化
    mm = MinMaxScaler()
    values=np.reshape(values,(values.shape[0],1))
    values=mm.fit_transform(values)
    train, test = values[0:Tp], values[Tp:]
    
    trainX, trainY = convertToMatrix(train, look_back,12)
    testX, testY = convertToMatrix(test, look_back,12)

    trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
    testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
    
    trainY= np.reshape(trainY, (trainY.shape[0],  trainY.shape[1]))
    testY= np.reshape(testY, (testY.shape[0],  testY.shape[1]))

    model = keras.models.Sequential([
        keras.layers.SimpleRNN(units=32, return_sequences=True, input_shape=(1,look_back)),
        keras.layers.SimpleRNN(32),
        keras.layers.Dense(12)
                                    ])
    model.summary()

    model.compile(loss="mse", optimizer="adam")
    history = model.fit(trainX, trainY, epochs=60,
                    validation_data=(testX, testY))

    #make predictions
    trainPredict = model.predict(trainX)
    testPredict = model.predict(testX)
    #invert predictions
    trainY= np.reshape(trainY, (trainY.shape[0],  trainY.shape[1]))
    testY= np.reshape(testY, (testY.shape[0],  testY.shape[1]))
    trainPredict = mm.inverse_transform(trainPredict)
    trainYb = mm.inverse_transform(trainY)
    testPredict = mm.inverse_transform(testPredict)
    testYb = mm.inverse_transform(testY)
    #calculate root mean squared error
    trainScore = math.sqrt(mean_squared_error(trainYb, trainPredict))
    print('Train Score: %.2f RMSE' % (trainScore))
    testScore = math.sqrt(mean_squared_error(testYb, testPredict))
    print('Test Score: %.2f RMSE' % (testScore))

    trainPredict=np.reshape(trainPredict,(-1,1))
    testPredict=np.reshape(testPredict,(-1,1))

    #shift train predictions for plotting
    trainPredictPlot = np.empty_like(values)
    trainPredictPlot[:, :] = np.nan
    trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
    #shift test predictions for plotting
    testPredictPlot = np.empty_like(values)
    testPredictPlot[:, :] = np.nan
    testPredictPlot[len(values)-len(testPredict)-12:len(values)-12, :] = testPredict
    #plot baseline and predictions
    plt.plot(mm.inverse_transform(values),label="Actual")
    plt.plot(trainPredictPlot,label="Train")
    plt.plot(testPredictPlot,label="Test")
    plt.title(i)    
    plt.legend()
    plt.show()
    df_prediction_RNN['Train_Prediction_'+i]=trainPredictPlot
    df_prediction_RNN['Test_Prediction_'+i]=testPredictPlot
# Out:
# C:\Users\卢博文\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_26 (SimpleRNN)            │ (None, 1, 32)               │           2,976 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_27 (SimpleRNN)            │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 12)                  │             396 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,452 (21.30 KB)
#  Trainable params: 5,452 (21.30 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - loss: 0.0312 - val_loss: 0.1836
# Epoch 2/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0112 - val_loss: 0.0809
# Epoch 3/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0062 - val_loss: 0.0407
# Epoch 4/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0044 - val_loss: 0.0360
# Epoch 5/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0035 - val_loss: 0.0398
# Epoch 6/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0032 - val_loss: 0.0332
# Epoch 7/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0027 - val_loss: 0.0272
# Epoch 8/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0027 - val_loss: 0.0245
# Epoch 9/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0023 - val_loss: 0.0244
# Epoch 10/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0022 - val_loss: 0.0253
# Epoch 11/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0016 - val_loss: 0.0219
# Epoch 12/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0016 - val_loss: 0.0179
# Epoch 13/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0015 - val_loss: 0.0178
# Epoch 14/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0016 - val_loss: 0.0208
# Epoch 15/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014 - val_loss: 0.0202
# Epoch 16/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0015 - val_loss: 0.0169
# Epoch 17/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0011 - val_loss: 0.0159
# Epoch 18/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0011 - val_loss: 0.0158
# Epoch 19/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.7380e-04 - val_loss: 0.0162
# Epoch 20/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.3268e-04 - val_loss: 0.0157
# Epoch 21/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0011 - val_loss: 0.0153
# Epoch 22/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0011 - val_loss: 0.0161
# Epoch 23/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.3229e-04 - val_loss: 0.0150
# Epoch 24/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.7566e-04 - val_loss: 0.0160
# Epoch 25/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.6500e-04 - val_loss: 0.0162
# Epoch 26/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.0996e-04 - val_loss: 0.0146
# Epoch 27/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.8633e-04 - val_loss: 0.0152
# Epoch 28/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.2054e-04 - val_loss: 0.0168
# Epoch 29/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.7400e-04 - val_loss: 0.0168
# Epoch 30/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.9053e-04 - val_loss: 0.0149
# Epoch 31/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.9833e-04 - val_loss: 0.0154
# Epoch 32/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.4404e-04 - val_loss: 0.0156
# Epoch 33/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.8902e-04 - val_loss: 0.0153
# Epoch 34/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.4561e-04 - val_loss: 0.0173
# Epoch 35/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.7952e-04 - val_loss: 0.0146
# Epoch 36/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.7088e-04 - val_loss: 0.0141
# Epoch 37/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.0134e-04 - val_loss: 0.0182
# Epoch 38/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.9952e-04 - val_loss: 0.0160
# Epoch 39/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.6325e-04 - val_loss: 0.0147
# Epoch 40/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.7195e-04 - val_loss: 0.0148
# Epoch 41/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.3355e-04 - val_loss: 0.0157
# Epoch 42/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.9125e-04 - val_loss: 0.0162
# Epoch 43/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.1363e-04 - val_loss: 0.0164
# Epoch 44/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.9024e-04 - val_loss: 0.0134
# Epoch 45/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.6003e-04 - val_loss: 0.0163
# Epoch 46/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.5915e-04 - val_loss: 0.0154
# Epoch 47/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.7520e-04 - val_loss: 0.0144
# Epoch 48/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.7401e-04 - val_loss: 0.0146
# Epoch 49/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.1347e-04 - val_loss: 0.0145
# Epoch 50/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.1901e-04 - val_loss: 0.0152
# Epoch 51/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0869e-04 - val_loss: 0.0163
# Epoch 52/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.2011e-04 - val_loss: 0.0130
# Epoch 53/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8201e-04 - val_loss: 0.0156
# Epoch 54/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8306e-04 - val_loss: 0.0147
# Epoch 55/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.6715e-04 - val_loss: 0.0146
# Epoch 56/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.9141e-04 - val_loss: 0.0133
# Epoch 57/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.6042e-04 - val_loss: 0.0146
# Epoch 58/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.1453e-04 - val_loss: 0.0162
# Epoch 59/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.9653e-04 - val_loss: 0.0135
# Epoch 60/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.0318e-04 - val_loss: 0.0138
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Train Score: 4.12 RMSE
# Test Score: 20.59 RMSE
# C:\Users\卢博文\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_28 (SimpleRNN)            │ (None, 1, 32)               │           2,976 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_29 (SimpleRNN)            │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 12)                  │             396 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,452 (21.30 KB)
#  Trainable params: 5,452 (21.30 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 412ms/step - loss: 0.0194 - val_loss: 0.5439
# Epoch 2/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0089 - val_loss: 0.3361
# Epoch 3/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0052 - val_loss: 0.2168
# Epoch 4/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0051 - val_loss: 0.1526
# Epoch 5/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0037 - val_loss: 0.1151
# Epoch 6/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0028 - val_loss: 0.0917
# Epoch 7/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0020 - val_loss: 0.0783
# Epoch 8/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0017 - val_loss: 0.0700
# Epoch 9/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0632
# Epoch 10/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0010 - val_loss: 0.0558
# Epoch 11/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0010 - val_loss: 0.0492
# Epoch 12/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0010 - val_loss: 0.0444
# Epoch 13/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.7495e-04 - val_loss: 0.0422
# Epoch 14/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.2785e-04 - val_loss: 0.0398
# Epoch 15/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.4401e-04 - val_loss: 0.0379
# Epoch 16/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.6451e-04 - val_loss: 0.0370
# Epoch 17/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.7241e-04 - val_loss: 0.0362
# Epoch 18/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.6064e-04 - val_loss: 0.0354
# Epoch 19/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.7849e-04 - val_loss: 0.0340
# Epoch 20/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.2223e-04 - val_loss: 0.0329
# Epoch 21/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8862e-04 - val_loss: 0.0319
# Epoch 22/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.8755e-04 - val_loss: 0.0310
# Epoch 23/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.8350e-04 - val_loss: 0.0303
# Epoch 24/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3936e-04 - val_loss: 0.0300
# Epoch 25/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.9541e-04 - val_loss: 0.0297
# Epoch 26/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5650e-04 - val_loss: 0.0295
# Epoch 27/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6518e-04 - val_loss: 0.0288
# Epoch 28/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7113e-04 - val_loss: 0.0282
# Epoch 29/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.8164e-04 - val_loss: 0.0277
# Epoch 30/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.9682e-04 - val_loss: 0.0270
# Epoch 31/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.3453e-04 - val_loss: 0.0266
# Epoch 32/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.5838e-04 - val_loss: 0.0262
# Epoch 33/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.5317e-04 - val_loss: 0.0259
# Epoch 34/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9017e-04 - val_loss: 0.0257
# Epoch 35/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7832e-04 - val_loss: 0.0257
# Epoch 36/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7874e-04 - val_loss: 0.0256
# Epoch 37/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.4381e-04 - val_loss: 0.0253
# Epoch 38/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.4199e-04 - val_loss: 0.0251
# Epoch 39/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7872e-04 - val_loss: 0.0250
# Epoch 40/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4767e-04 - val_loss: 0.0249
# Epoch 41/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5088e-04 - val_loss: 0.0248
# Epoch 42/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6990e-04 - val_loss: 0.0248
# Epoch 43/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.2726e-04 - val_loss: 0.0245
# Epoch 44/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3421e-04 - val_loss: 0.0243
# Epoch 45/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.5526e-04 - val_loss: 0.0243
# Epoch 46/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9838e-04 - val_loss: 0.0242
# Epoch 47/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.4912e-04 - val_loss: 0.0239
# Epoch 48/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.0472e-04 - val_loss: 0.0237
# Epoch 49/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.2006e-04 - val_loss: 0.0238
# Epoch 50/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9734e-04 - val_loss: 0.0238
# Epoch 51/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3225e-04 - val_loss: 0.0237
# Epoch 52/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3840e-04 - val_loss: 0.0235
# Epoch 53/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.5136e-04 - val_loss: 0.0232
# Epoch 54/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0918e-04 - val_loss: 0.0230
# Epoch 55/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1502e-04 - val_loss: 0.0232
# Epoch 56/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.4825e-04 - val_loss: 0.0233
# Epoch 57/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3653e-04 - val_loss: 0.0234
# Epoch 58/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7877e-04 - val_loss: 0.0232
# Epoch 59/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0052e-04 - val_loss: 0.0226
# Epoch 60/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9325e-04 - val_loss: 0.0224
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step
# Train Score: 5.72 RMSE
# Test Score: 59.97 RMSE
# C:\Users\卢博文\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_30 (SimpleRNN)            │ (None, 1, 32)               │           2,976 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_31 (SimpleRNN)            │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 12)                  │             396 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,452 (21.30 KB)
#  Trainable params: 5,452 (21.30 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - loss: 0.1089 - val_loss: 0.6904
# Epoch 2/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0516 - val_loss: 0.4328
# Epoch 3/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0308 - val_loss: 0.2581
# Epoch 4/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0150 - val_loss: 0.1512
# Epoch 5/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0088 - val_loss: 0.0909
# Epoch 6/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0054 - val_loss: 0.0606
# Epoch 7/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0046 - val_loss: 0.0466
# Epoch 8/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0041 - val_loss: 0.0438
# Epoch 9/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0037 - val_loss: 0.0488
# Epoch 10/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0033 - val_loss: 0.0579
# Epoch 11/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030 - val_loss: 0.0663
# Epoch 12/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026 - val_loss: 0.0717
# Epoch 13/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021 - val_loss: 0.0731
# Epoch 14/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - val_loss: 0.0722
# Epoch 15/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - val_loss: 0.0702
# Epoch 16/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - val_loss: 0.0674
# Epoch 17/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0644
# Epoch 18/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - val_loss: 0.0618
# Epoch 19/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0012 - val_loss: 0.0590
# Epoch 20/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0011 - val_loss: 0.0568
# Epoch 21/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.3121e-04 - val_loss: 0.0554
# Epoch 22/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.9233e-04 - val_loss: 0.0539
# Epoch 23/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.0970e-04 - val_loss: 0.0528
# Epoch 24/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.4249e-04 - val_loss: 0.0516
# Epoch 25/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.0758e-04 - val_loss: 0.0500
# Epoch 26/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.4613e-04 - val_loss: 0.0487
# Epoch 27/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.1481e-04 - val_loss: 0.0476
# Epoch 28/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.2647e-04 - val_loss: 0.0466
# Epoch 29/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.6377e-04 - val_loss: 0.0461
# Epoch 30/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.3899e-04 - val_loss: 0.0459
# Epoch 31/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7836e-04 - val_loss: 0.0454
# Epoch 32/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.2014e-04 - val_loss: 0.0445
# Epoch 33/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.2327e-04 - val_loss: 0.0439
# Epoch 34/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.3494e-04 - val_loss: 0.0428
# Epoch 35/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.4546e-04 - val_loss: 0.0419
# Epoch 36/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.5706e-04 - val_loss: 0.0413
# Epoch 37/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.0680e-04 - val_loss: 0.0404
# Epoch 38/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4098e-04 - val_loss: 0.0398
# Epoch 39/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4833e-04 - val_loss: 0.0396
# Epoch 40/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.3380e-04 - val_loss: 0.0391
# Epoch 41/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.1083e-04 - val_loss: 0.0380
# Epoch 42/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.1368e-04 - val_loss: 0.0374
# Epoch 43/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.1328e-04 - val_loss: 0.0372
# Epoch 44/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.6091e-04 - val_loss: 0.0368
# Epoch 45/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.3643e-04 - val_loss: 0.0363
# Epoch 46/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.3997e-04 - val_loss: 0.0361
# Epoch 47/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.3887e-04 - val_loss: 0.0355
# Epoch 48/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.3706e-04 - val_loss: 0.0353
# Epoch 49/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9497e-04 - val_loss: 0.0346
# Epoch 50/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.0210e-04 - val_loss: 0.0341
# Epoch 51/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.8010e-04 - val_loss: 0.0338
# Epoch 52/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.2072e-04 - val_loss: 0.0335
# Epoch 53/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.7998e-04 - val_loss: 0.0338
# Epoch 54/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.3161e-04 - val_loss: 0.0333
# Epoch 55/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.3986e-04 - val_loss: 0.0332
# Epoch 56/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.3765e-04 - val_loss: 0.0325
# Epoch 57/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.4255e-04 - val_loss: 0.0322
# Epoch 58/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.3622e-04 - val_loss: 0.0324
# Epoch 59/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.0975e-04 - val_loss: 0.0318
# Epoch 60/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0287e-04 - val_loss: 0.0314
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Train Score: 7.97 RMSE
# Test Score: 67.76 RMSE
# C:\Users\卢博文\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_32 (SimpleRNN)            │ (None, 1, 32)               │           2,976 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_33 (SimpleRNN)            │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 12)                  │             396 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,452 (21.30 KB)
#  Trainable params: 5,452 (21.30 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 142ms/step - loss: 0.0083 - val_loss: 0.1983
# Epoch 2/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0033 - val_loss: 0.1099
# Epoch 3/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - val_loss: 0.0652
# Epoch 4/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.4076e-04 - val_loss: 0.0435
# Epoch 5/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.5438e-04 - val_loss: 0.0353
# Epoch 6/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.8428e-04 - val_loss: 0.0341
# Epoch 7/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.9484e-04 - val_loss: 0.0336
# Epoch 8/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.6833e-04 - val_loss: 0.0334
# Epoch 9/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.0845e-04 - val_loss: 0.0333
# Epoch 10/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2486e-04 - val_loss: 0.0336
# Epoch 11/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7731e-04 - val_loss: 0.0337
# Epoch 12/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.2515e-04 - val_loss: 0.0336
# Epoch 13/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0680e-04 - val_loss: 0.0324
# Epoch 14/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7526e-04 - val_loss: 0.0306
# Epoch 15/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6577e-04 - val_loss: 0.0280
# Epoch 16/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7336e-04 - val_loss: 0.0250
# Epoch 17/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2653e-04 - val_loss: 0.0227
# Epoch 18/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2254e-04 - val_loss: 0.0208
# Epoch 19/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1331e-04 - val_loss: 0.0194
# Epoch 20/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0786e-04 - val_loss: 0.0184
# Epoch 21/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0139e-04 - val_loss: 0.0178
# Epoch 22/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.6438e-05 - val_loss: 0.0171
# Epoch 23/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.7797e-05 - val_loss: 0.0169
# Epoch 24/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.7936e-05 - val_loss: 0.0165
# Epoch 25/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.2307e-05 - val_loss: 0.0160
# Epoch 26/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.1237e-05 - val_loss: 0.0155
# Epoch 27/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.1291e-05 - val_loss: 0.0151
# Epoch 28/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.0480e-05 - val_loss: 0.0146
# Epoch 29/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4047e-05 - val_loss: 0.0141
# Epoch 30/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4933e-05 - val_loss: 0.0136
# Epoch 31/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8797e-05 - val_loss: 0.0134
# Epoch 32/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.2062e-05 - val_loss: 0.0133
# Epoch 33/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.2862e-05 - val_loss: 0.0129
# Epoch 34/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.9303e-05 - val_loss: 0.0127
# Epoch 35/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.0314e-05 - val_loss: 0.0124
# Epoch 36/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.2561e-05 - val_loss: 0.0123
# Epoch 37/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9840e-05 - val_loss: 0.0120
# Epoch 38/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.4927e-05 - val_loss: 0.0118
# Epoch 39/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.2899e-05 - val_loss: 0.0117
# Epoch 40/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.1095e-05 - val_loss: 0.0117
# Epoch 41/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.9235e-05 - val_loss: 0.0116
# Epoch 42/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.4806e-05 - val_loss: 0.0114
# Epoch 43/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.8510e-05 - val_loss: 0.0114
# Epoch 44/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.0678e-05 - val_loss: 0.0114
# Epoch 45/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5906e-05 - val_loss: 0.0112
# Epoch 46/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.7817e-05 - val_loss: 0.0110
# Epoch 47/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.8540e-05 - val_loss: 0.0110
# Epoch 48/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.0698e-05 - val_loss: 0.0110
# Epoch 49/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.7008e-05 - val_loss: 0.0110
# Epoch 50/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.3797e-05 - val_loss: 0.0108
# Epoch 51/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.1735e-05 - val_loss: 0.0108
# Epoch 52/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.3243e-05 - val_loss: 0.0109
# Epoch 53/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9925e-05 - val_loss: 0.0108
# Epoch 54/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.4428e-05 - val_loss: 0.0107
# Epoch 55/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.7479e-05 - val_loss: 0.0106
# Epoch 56/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.3609e-05 - val_loss: 0.0105
# Epoch 57/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.3873e-05 - val_loss: 0.0105
# Epoch 58/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.4201e-05 - val_loss: 0.0105
# Epoch 59/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.6687e-05 - val_loss: 0.0105
# Epoch 60/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.3220e-05 - val_loss: 0.0104
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Train Score: 6.75 RMSE
# Test Score: 108.01 RMSE
# C:\Users\卢博文\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_34 (SimpleRNN)            │ (None, 1, 32)               │           2,976 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_35 (SimpleRNN)            │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 12)                  │             396 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,452 (21.30 KB)
#  Trainable params: 5,452 (21.30 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - loss: 0.1763 - val_loss: 1.0504
# Epoch 2/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1021 - val_loss: 0.6972
# Epoch 3/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0617 - val_loss: 0.4530
# Epoch 4/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0361 - val_loss: 0.3004
# Epoch 5/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0193 - val_loss: 0.2081
# Epoch 6/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0101 - val_loss: 0.1512
# Epoch 7/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0070 - val_loss: 0.1127
# Epoch 8/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0058 - val_loss: 0.0878
# Epoch 9/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0051 - val_loss: 0.0721
# Epoch 10/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0046 - val_loss: 0.0656
# Epoch 11/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0039 - val_loss: 0.0666
# Epoch 12/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0033 - val_loss: 0.0723
# Epoch 13/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0032 - val_loss: 0.0789
# Epoch 14/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029 - val_loss: 0.0843
# Epoch 15/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0027 - val_loss: 0.0867
# Epoch 16/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0025 - val_loss: 0.0864
# Epoch 17/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0024 - val_loss: 0.0838
# Epoch 18/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0022 - val_loss: 0.0822
# Epoch 19/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0019 - val_loss: 0.0808
# Epoch 20/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0019 - val_loss: 0.0803
# Epoch 21/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0019 - val_loss: 0.0808
# Epoch 22/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0019 - val_loss: 0.0797
# Epoch 23/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0019 - val_loss: 0.0793
# Epoch 24/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0017 - val_loss: 0.0787
# Epoch 25/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0018 - val_loss: 0.0783
# Epoch 26/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0016 - val_loss: 0.0776
# Epoch 27/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0016 - val_loss: 0.0765
# Epoch 28/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0016 - val_loss: 0.0762
# Epoch 29/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015 - val_loss: 0.0753
# Epoch 30/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015 - val_loss: 0.0739
# Epoch 31/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015 - val_loss: 0.0724
# Epoch 32/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0711
# Epoch 33/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0710
# Epoch 34/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014 - val_loss: 0.0711
# Epoch 35/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0709
# Epoch 36/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015 - val_loss: 0.0705
# Epoch 37/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0702
# Epoch 38/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0698
# Epoch 39/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0697
# Epoch 40/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0013 - val_loss: 0.0695
# Epoch 41/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0012 - val_loss: 0.0686
# Epoch 42/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0012 - val_loss: 0.0676
# Epoch 43/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0012 - val_loss: 0.0664
# Epoch 44/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0012 - val_loss: 0.0663
# Epoch 45/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0662
# Epoch 46/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0010 - val_loss: 0.0661
# Epoch 47/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0012 - val_loss: 0.0658
# Epoch 48/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - val_loss: 0.0655
# Epoch 49/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0011 - val_loss: 0.0649
# Epoch 50/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0011 - val_loss: 0.0636
# Epoch 51/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0010 - val_loss: 0.0633
# Epoch 52/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.5888e-04 - val_loss: 0.0629
# Epoch 53/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.8295e-04 - val_loss: 0.0629
# Epoch 54/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0011 - val_loss: 0.0628
# Epoch 55/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.9982e-04 - val_loss: 0.0626
# Epoch 56/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.8564e-04 - val_loss: 0.0619
# Epoch 57/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0011 - val_loss: 0.0623
# Epoch 58/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.5779e-04 - val_loss: 0.0619
# Epoch 59/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.4759e-04 - val_loss: 0.0606
# Epoch 60/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.9572e-04 - val_loss: 0.0600
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step
# Train Score: 4.39 RMSE
# Test Score: 35.21 RMSE
# C:\Users\卢博文\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_36 (SimpleRNN)            │ (None, 1, 32)               │           2,976 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_37 (SimpleRNN)            │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 12)                  │             396 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,452 (21.30 KB)
#  Trainable params: 5,452 (21.30 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - loss: 0.2202 - val_loss: 0.5336
# Epoch 2/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1156 - val_loss: 0.3152
# Epoch 3/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0509 - val_loss: 0.1864
# Epoch 4/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0295 - val_loss: 0.1131
# Epoch 5/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0220 - val_loss: 0.0744
# Epoch 6/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0146 - val_loss: 0.0540
# Epoch 7/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0124 - val_loss: 0.0423
# Epoch 8/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0124 - val_loss: 0.0363
# Epoch 9/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0126 - val_loss: 0.0343
# Epoch 10/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0111 - val_loss: 0.0350
# Epoch 11/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0112 - val_loss: 0.0373
# Epoch 12/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0079 - val_loss: 0.0423
# Epoch 13/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0073 - val_loss: 0.0472
# Epoch 14/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0080 - val_loss: 0.0505
# Epoch 15/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0069 - val_loss: 0.0519
# Epoch 16/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0048 - val_loss: 0.0519
# Epoch 17/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0068 - val_loss: 0.0491
# Epoch 18/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0071 - val_loss: 0.0450
# Epoch 19/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0053 - val_loss: 0.0415
# Epoch 20/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0052 - val_loss: 0.0386
# Epoch 21/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0046 - val_loss: 0.0355
# Epoch 22/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0042 - val_loss: 0.0331
# Epoch 23/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0052 - val_loss: 0.0311
# Epoch 24/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0052 - val_loss: 0.0304
# Epoch 25/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0047 - val_loss: 0.0301
# Epoch 26/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0035 - val_loss: 0.0303
# Epoch 27/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0042 - val_loss: 0.0297
# Epoch 28/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0040 - val_loss: 0.0287
# Epoch 29/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0045 - val_loss: 0.0272
# Epoch 30/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0041 - val_loss: 0.0263
# Epoch 31/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0032 - val_loss: 0.0255
# Epoch 32/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0032 - val_loss: 0.0246
# Epoch 33/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0033 - val_loss: 0.0235
# Epoch 34/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0035 - val_loss: 0.0225
# Epoch 35/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0039 - val_loss: 0.0213
# Epoch 36/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0033 - val_loss: 0.0212
# Epoch 37/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0030 - val_loss: 0.0212
# Epoch 38/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0026 - val_loss: 0.0211
# Epoch 39/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0034 - val_loss: 0.0198
# Epoch 40/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0029 - val_loss: 0.0190
# Epoch 41/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0032 - val_loss: 0.0184
# Epoch 42/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0034 - val_loss: 0.0179
# Epoch 43/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0032 - val_loss: 0.0177
# Epoch 44/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030 - val_loss: 0.0174
# Epoch 45/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0028 - val_loss: 0.0174
# Epoch 46/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0030 - val_loss: 0.0166
# Epoch 47/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0029 - val_loss: 0.0161
# Epoch 48/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0024 - val_loss: 0.0163
# Epoch 49/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028 - val_loss: 0.0157
# Epoch 50/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0024 - val_loss: 0.0151
# Epoch 51/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0024 - val_loss: 0.0147
# Epoch 52/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0022 - val_loss: 0.0145
# Epoch 53/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0025 - val_loss: 0.0147
# Epoch 54/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0024 - val_loss: 0.0147
# Epoch 55/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0025 - val_loss: 0.0142
# Epoch 56/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025 - val_loss: 0.0140
# Epoch 57/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0021 - val_loss: 0.0137
# Epoch 58/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0020 - val_loss: 0.0135
# Epoch 59/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0018 - val_loss: 0.0134
# Epoch 60/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0020 - val_loss: 0.0129
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Train Score: 7.43 RMSE
# Test Score: 18.76 RMSE
# C:\Users\卢博文\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_38 (SimpleRNN)            │ (None, 1, 32)               │           2,976 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_39 (SimpleRNN)            │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 12)                  │             396 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,452 (21.30 KB)
#  Trainable params: 5,452 (21.30 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - loss: 0.0663 - val_loss: 0.2315
# Epoch 2/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0316 - val_loss: 0.1396
# Epoch 3/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0154 - val_loss: 0.0876
# Epoch 4/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0087 - val_loss: 0.0587
# Epoch 5/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0061 - val_loss: 0.0426
# Epoch 6/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0052 - val_loss: 0.0352
# Epoch 7/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0044 - val_loss: 0.0349
# Epoch 8/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0045 - val_loss: 0.0369
# Epoch 9/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0040 - val_loss: 0.0382
# Epoch 10/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0036 - val_loss: 0.0388
# Epoch 11/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0028 - val_loss: 0.0400
# Epoch 12/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0029 - val_loss: 0.0415
# Epoch 13/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021 - val_loss: 0.0430
# Epoch 14/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025 - val_loss: 0.0435
# Epoch 15/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021 - val_loss: 0.0436
# Epoch 16/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0024 - val_loss: 0.0421
# Epoch 17/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023 - val_loss: 0.0401
# Epoch 18/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0020 - val_loss: 0.0382
# Epoch 19/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0019 - val_loss: 0.0366
# Epoch 20/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0019 - val_loss: 0.0353
# Epoch 21/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018 - val_loss: 0.0345
# Epoch 22/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0019 - val_loss: 0.0343
# Epoch 23/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0019 - val_loss: 0.0341
# Epoch 24/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018 - val_loss: 0.0337
# Epoch 25/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016 - val_loss: 0.0337
# Epoch 26/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - val_loss: 0.0337
# Epoch 27/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0019 - val_loss: 0.0333
# Epoch 28/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018 - val_loss: 0.0323
# Epoch 29/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016 - val_loss: 0.0317
# Epoch 30/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - val_loss: 0.0316
# Epoch 31/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018 - val_loss: 0.0307
# Epoch 32/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0017 - val_loss: 0.0300
# Epoch 33/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - val_loss: 0.0294
# Epoch 34/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - val_loss: 0.0295
# Epoch 35/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0017 - val_loss: 0.0289
# Epoch 36/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - val_loss: 0.0285
# Epoch 37/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - val_loss: 0.0281
# Epoch 38/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014 - val_loss: 0.0280
# Epoch 39/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - val_loss: 0.0277
# Epoch 40/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - val_loss: 0.0275
# Epoch 41/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - val_loss: 0.0267
# Epoch 42/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - val_loss: 0.0259
# Epoch 43/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - val_loss: 0.0257
# Epoch 44/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - val_loss: 0.0255
# Epoch 45/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - val_loss: 0.0253
# Epoch 46/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - val_loss: 0.0247
# Epoch 47/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - val_loss: 0.0243
# Epoch 48/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - val_loss: 0.0243
# Epoch 49/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - val_loss: 0.0236
# Epoch 50/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011 - val_loss: 0.0236
# Epoch 51/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - val_loss: 0.0231
# Epoch 52/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - val_loss: 0.0225
# Epoch 53/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0010 - val_loss: 0.0223
# Epoch 54/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011 - val_loss: 0.0224
# Epoch 55/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - val_loss: 0.0216
# Epoch 56/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011 - val_loss: 0.0215
# Epoch 57/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011 - val_loss: 0.0214
# Epoch 58/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.7073e-04 - val_loss: 0.0211
# Epoch 59/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011 - val_loss: 0.0206
# Epoch 60/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011 - val_loss: 0.0205
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Train Score: 14.02 RMSE
# Test Score: 62.82 RMSE

# %%
df_prediction_RNN.head()

# %%
#df_prediction_RNN.to_csv('RNN.csv',index = True)

# %%
big_7_return.head()
# Out:
# Ticker           AAPL       AMZN      GOOGL        META       MSFT    NVDA  \
# Date
# 2016-01-04  26.337500  31.849501  37.972000  102.220001  54.799999  8.0925
# 2016-01-05  25.677500  31.689501  38.076500  102.730003  55.049999  8.2225
# 2016-01-06  25.174999  31.632500  37.966499  102.970001  54.049999  7.8825
# 2016-01-07  24.112499  30.396999  37.049999   97.919998  52.169998  7.5700
# 2016-01-08  24.240000  30.352501  36.545502   97.330002  52.330002  7.4075
#
# Ticker           TSLA
# Date
# 2016-01-04  14.894000
# 2016-01-05  14.895333
# 2016-01-06  14.602667
# 2016-01-07  14.376667
# 2016-01-08  14.066667

# %%
df_prediction_LSTM = pd.DataFrame(data = {'Observed': y},index = y.index)

# %%
for i in ['AAPL','TSLA', 'MSFT','NVDA','GOOGL','AMZN','META']:
    y=big_7_return[i]
    # 循环神经网络方法训练
    look_back=60
    Tp = 1200
    values = y.values
    #归一化
    mm = MinMaxScaler()
    values=np.reshape(values,(values.shape[0],1))
    values=mm.fit_transform(values)
    train, test = values[0:Tp], values[Tp:]
    look_back = 1
    trainXb, trainYb = step_ahead(train, look_back)
    testXb, testYb = step_ahead(test, look_back)
    trainX = np.reshape(trainXb, (trainXb.shape[0], 1, trainXb.shape[1]))
    testX = np.reshape(testXb, (testXb.shape[0], 1, testXb.shape[1]))
    #create and fit the LSTM network
    model = Sequential()
    model.add(LSTM(256, input_shape=(1, look_back)))
    
    model.add(Dense(1))
    model.summary()
    
    and_i_stop = EarlyStopping(monitor = 'loss', patience = 4, mode = 'auto')
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.fit(trainX, trainYb, epochs=10, callbacks = [and_i_stop], batch_size=1, verbose=2)
    #make predictions
    trainPredict = model.predict(trainX)
    testPredict = model.predict(testX)
    #invert predictions
    trainPredict = mm.inverse_transform(trainPredict)
    trainY = mm.inverse_transform(trainYb)
    testPredict = mm.inverse_transform(testPredict)
    testY = mm.inverse_transform(testYb)
    #calculate root mean squared error
    trainScore = math.sqrt(mean_squared_error(trainY, trainPredict))
    print('Train Score: %.2f RMSE' % (trainScore))
    testScore = math.sqrt(mean_squared_error(testY, testPredict))
    print('Test Score: %.2f RMSE' % (testScore))
    #shift train predictions for plotting
    trainPredictPlot = np.empty_like(values)
    trainPredictPlot[:, :] = np.nan
    trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
    #shift test predictions for plotting
    testPredictPlot = np.empty_like(values)
    testPredictPlot[:, :] = np.nan
    testPredictPlot[len(trainPredict)+(look_back*2)+1:len(values)-1, :] = testPredict
    #plot baseline and predictions
    plt.plot(mm.inverse_transform(values),label="Actual")
    plt.plot(trainPredictPlot,label="Train")
    plt.plot(testPredictPlot,label="Test")
    plt.title(i) 
    plt.legend()
    plt.show()
    df_prediction_LSTM['Train_Prediction_'+i]=trainPredictPlot
    df_prediction_LSTM['Test_Prediction_'+i]=testPredictPlot
# Out:
# C:\Users\卢博文\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 256)                 │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 1)                   │             257 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 264,449 (1.01 MB)
#  Trainable params: 264,449 (1.01 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 1198/1198 - 3s - 3ms/step - loss: 0.0026
# Epoch 2/10
# 1198/1198 - 1s - 953us/step - loss: 7.8177e-05
# Epoch 3/10
# 1198/1198 - 1s - 941us/step - loss: 8.7821e-05
# Epoch 4/10
# 1198/1198 - 1s - 919us/step - loss: 8.6538e-05
# Epoch 5/10
# 1198/1198 - 1s - 921us/step - loss: 8.9161e-05
# Epoch 6/10
# 1198/1198 - 1s - 917us/step - loss: 9.4304e-05
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step
# Train Score: 1.46 RMSE
# Test Score: 2.83 RMSE
# C:\Users\卢博文\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_21"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                        │ (None, 256)                 │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_21 (Dense)                     │ (None, 1)                   │             257 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 264,449 (1.01 MB)
#  Trainable params: 264,449 (1.01 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 1198/1198 - 2s - 2ms/step - loss: 8.0520e-04
# Epoch 2/10
# 1198/1198 - 1s - 926us/step - loss: 5.1443e-05
# Epoch 3/10
# 1198/1198 - 1s - 1ms/step - loss: 5.6880e-05
# Epoch 4/10
# 1198/1198 - 1s - 947us/step - loss: 5.7229e-05
# Epoch 5/10
# 1198/1198 - 1s - 930us/step - loss: 6.2481e-05
# Epoch 6/10
# 1198/1198 - 1s - 985us/step - loss: 5.0304e-05
# Epoch 7/10
# 1198/1198 - 1s - 945us/step - loss: 4.8399e-05
# Epoch 8/10
# 1198/1198 - 1s - 925us/step - loss: 6.4230e-05
# Epoch 9/10
# 1198/1198 - 1s - 923us/step - loss: 5.0896e-05
# Epoch 10/10
# 1198/1198 - 1s - 919us/step - loss: 4.9572e-05
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step
# Train Score: 2.83 RMSE
# Test Score: 13.06 RMSE
# C:\Users\卢博文\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_22"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                        │ (None, 256)                 │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_22 (Dense)                     │ (None, 1)                   │             257 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 264,449 (1.01 MB)
#  Trainable params: 264,449 (1.01 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 1198/1198 - 2s - 2ms/step - loss: 0.0020
# Epoch 2/10
# 1198/1198 - 1s - 945us/step - loss: 6.1744e-05
# Epoch 3/10
# 1198/1198 - 1s - 977us/step - loss: 6.8481e-05
# Epoch 4/10
# 1198/1198 - 1s - 989us/step - loss: 7.3411e-05
# Epoch 5/10
# 1198/1198 - 1s - 958us/step - loss: 7.3387e-05
# Epoch 6/10
# 1198/1198 - 1s - 970us/step - loss: 7.2805e-05
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step
# Train Score: 3.05 RMSE
# Test Score: 9.81 RMSE
# C:\Users\卢博文\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_23"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                        │ (None, 256)                 │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_23 (Dense)                     │ (None, 1)                   │             257 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 264,449 (1.01 MB)
#  Trainable params: 264,449 (1.01 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 1198/1198 - 2s - 2ms/step - loss: 9.7097e-05
# Epoch 2/10
# 1198/1198 - 1s - 977us/step - loss: 5.0848e-06
# Epoch 3/10
# 1198/1198 - 1s - 927us/step - loss: 6.8682e-06
# Epoch 4/10
# 1198/1198 - 1s - 930us/step - loss: 7.0745e-06
# Epoch 5/10
# 1198/1198 - 1s - 926us/step - loss: 6.8996e-06
# Epoch 6/10
# 1198/1198 - 1s - 924us/step - loss: 5.4749e-06
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step
# Train Score: 4.31 RMSE
# Test Score: 22.10 RMSE
# C:\Users\卢博文\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_24"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                        │ (None, 256)                 │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_24 (Dense)                     │ (None, 1)                   │             257 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 264,449 (1.01 MB)
#  Trainable params: 264,449 (1.01 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 1198/1198 - 2s - 2ms/step - loss: 8.8260e-04
# Epoch 2/10
# 1198/1198 - 1s - 923us/step - loss: 6.6483e-05
# Epoch 3/10
# 1198/1198 - 1s - 980us/step - loss: 6.9106e-05
# Epoch 4/10
# 1198/1198 - 1s - 922us/step - loss: 6.9602e-05
# Epoch 5/10
# 1198/1198 - 1s - 972us/step - loss: 7.5977e-05
# Epoch 6/10
# 1198/1198 - 1s - 954us/step - loss: 6.9946e-05
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step
# Train Score: 1.32 RMSE
# Test Score: 2.59 RMSE
# C:\Users\卢博文\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_25"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_5 (LSTM)                        │ (None, 256)                 │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_25 (Dense)                     │ (None, 1)                   │             257 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 264,449 (1.01 MB)
#  Trainable params: 264,449 (1.01 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 1198/1198 - 2s - 2ms/step - loss: 0.0042
# Epoch 2/10
# 1198/1198 - 1s - 971us/step - loss: 1.7612e-04
# Epoch 3/10
# 1198/1198 - 1s - 950us/step - loss: 1.7122e-04
# Epoch 4/10
# 1198/1198 - 1s - 976us/step - loss: 1.7046e-04
# Epoch 5/10
# 1198/1198 - 1s - 971us/step - loss: 1.7468e-04
# Epoch 6/10
# 1198/1198 - 1s - 970us/step - loss: 1.8910e-04
# Epoch 7/10
# 1198/1198 - 1s - 972us/step - loss: 2.2115e-04
# Epoch 8/10
# 1198/1198 - 1s - 970us/step - loss: 1.7491e-04
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step
# Train Score: 2.04 RMSE
# Test Score: 3.38 RMSE
# C:\Users\卢博文\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_26"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_6 (LSTM)                        │ (None, 256)                 │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_26 (Dense)                     │ (None, 1)                   │             257 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 264,449 (1.01 MB)
#  Trainable params: 264,449 (1.01 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 1198/1198 - 2s - 2ms/step - loss: 0.0015
# Epoch 2/10
# 1198/1198 - 1s - 1ms/step - loss: 9.3496e-05
# Epoch 3/10
# 1198/1198 - 1s - 1ms/step - loss: 1.0778e-04
# Epoch 4/10
# 1198/1198 - 1s - 941us/step - loss: 1.1862e-04
# Epoch 5/10
# 1198/1198 - 1s - 1ms/step - loss: 1.1507e-04
# Epoch 6/10
# 1198/1198 - 1s - 954us/step - loss: 1.0966e-04
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step
# Train Score: 4.86 RMSE
# Test Score: 8.78 RMSE

# %%
df_prediction_RNN.head()
# Out:
#              Observed  Train_Prediction_AAPL  Test_Prediction_AAPL  \
# Date
# 2016-01-04  31.849501                    NaN                   NaN
# 2016-01-05  31.689501                    NaN                   NaN
# 2016-01-06  31.632500                    NaN                   NaN
# 2016-01-07  30.396999                    NaN                   NaN
# 2016-01-08  30.352501                    NaN                   NaN
#
#             Train_Prediction_TSLA  Test_Prediction_TSLA  \
# Date
# 2016-01-04                    NaN                   NaN
# 2016-01-05                    NaN                   NaN
# 2016-01-06                    NaN                   NaN
# 2016-01-07                    NaN                   NaN
# 2016-01-08                    NaN                   NaN
#
#             Train_Prediction_MSFT  Test_Prediction_MSFT  \
# Date
# 2016-01-04                    NaN                   NaN
# 2016-01-05                    NaN                   NaN
# 2016-01-06                    NaN                   NaN
# 2016-01-07                    NaN                   NaN
# 2016-01-08                    NaN                   NaN
#
#             Train_Prediction_NVDA  Test_Prediction_NVDA  \
# Date
# 2016-01-04                    NaN                   NaN
# 2016-01-05                    NaN                   NaN
# 2016-01-06                    NaN                   NaN
# 2016-01-07                    NaN                   NaN
# 2016-01-08                    NaN                   NaN
#
#             Train_Prediction_GOOGL  Test_Prediction_GOOGL  \
# Date
# 2016-01-04                     NaN                    NaN
# 2016-01-05                     NaN                    NaN
# 2016-01-06                     NaN                    NaN
# 2016-01-07                     NaN                    NaN
# 2016-01-08                     NaN                    NaN
#
#             Train_Prediction_AMZN  Test_Prediction_AMZN  \
# Date
# 2016-01-04                    NaN                   NaN
# 2016-01-05                    NaN                   NaN
# 2016-01-06                    NaN                   NaN
# 2016-01-07                    NaN                   NaN
# 2016-01-08                    NaN                   NaN
#
#             Train_Prediction_META  Test_Prediction_META
# Date
# 2016-01-04                    NaN                   NaN
# 2016-01-05                    NaN                   NaN
# 2016-01-06                    NaN                   NaN
# 2016-01-07                    NaN                   NaN
# 2016-01-08                    NaN                   NaN

# %%
#df_prediction_LSTM.to_csv('LSTM.csv',index = True)
